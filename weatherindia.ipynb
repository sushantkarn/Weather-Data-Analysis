# %% [markdown]
# #Repository Link For The Dataset: https://www.kaggle.com/datasets/nelgiriyewithana/indian-weather-repository-daily-snapshot

# %%
import pandas as pd
data = pd.read_csv('/kaggle/input/indian-weather-repository-daily-snapshot/IndianWeatherRepository.csv')
print(data.head())
print(data.info())
print(data.describe())
# Out:
#   country location_name          region  latitude  longitude      timezone  \
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1693286100  2023-08-29 10:45                 27.5
# 1          1693286100  2023-08-29 10:45                 27.5
# 2          1693286100  2023-08-29 10:45                 26.3
# 3          1693286100  2023-08-29 10:45                 25.6
# 4          1693286100  2023-08-29 10:45                 27.2
#
#    temperature_fahrenheit  ... air_quality_PM2.5  air_quality_PM10  \
# 0                    81.5  ...              12.6              18.5
# 1                    81.5  ...              10.7              14.2
# 2                    79.3  ...              16.8              20.7
# 3                    78.1  ...               4.9               6.6
# 4                    81.0  ...              11.4              14.8
#
#    air_quality_us-epa-index  air_quality_gb-defra-index   sunrise    sunset  \
# 0                         1                           2  05:59 AM  06:41 PM
# 1                         1                           1  06:00 AM  06:40 PM
# 2                         2                           2  05:56 AM  06:34 PM
# 3                         1                           1  06:00 AM  06:38 PM
# 4                         1                           1  06:01 AM  06:39 PM
#
#    moonrise   moonset      moon_phase  moon_illumination
# 0  05:42 PM  03:38 AM  Waxing Gibbous                 93
# 1  05:39 PM  03:41 AM  Waxing Gibbous                 93
# 2  05:32 PM  03:39 AM  Waxing Gibbous                 93
# 3  05:36 PM  03:43 AM  Waxing Gibbous                 93
# 4  05:38 PM  03:42 AM  Waxing Gibbous                 93
#
# [5 rows x 42 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24070 entries, 0 to 24069
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       24070 non-null  object
#  1   location_name                 24070 non-null  object
#  2   region                        24070 non-null  object
#  3   latitude                      24070 non-null  float64
#  4   longitude                     24070 non-null  float64
#  5   timezone                      24070 non-null  object
#  6   last_updated_epoch            24070 non-null  int64
#  7   last_updated                  24070 non-null  object
#  8   temperature_celsius           24070 non-null  float64
#  9   temperature_fahrenheit        24070 non-null  float64
#  10  condition_text                24070 non-null  object
#  11  wind_mph                      24070 non-null  float64
#  12  wind_kph                      24070 non-null  float64
#  13  wind_degree                   24070 non-null  int64
#  14  wind_direction                24070 non-null  object
#  15  pressure_mb                   24070 non-null  float64
#  16  pressure_in                   24070 non-null  float64
#  17  precip_mm                     24070 non-null  float64
#  18  precip_in                     24070 non-null  float64
#  19  humidity                      24070 non-null  int64
#  20  cloud                         24070 non-null  int64
#  21  feels_like_celsius            24070 non-null  float64
#  22  feels_like_fahrenheit         24070 non-null  float64
#  23  visibility_km                 24070 non-null  float64
#  24  visibility_miles              24070 non-null  float64
#  25  uv_index                      24070 non-null  float64
#  26  gust_mph                      24070 non-null  float64
#  27  gust_kph                      24070 non-null  float64
#  28  air_quality_Carbon_Monoxide   24070 non-null  float64
#  29  air_quality_Ozone             24070 non-null  float64
#  30  air_quality_Nitrogen_dioxide  24070 non-null  float64
#  31  air_quality_Sulphur_dioxide   24070 non-null  float64
#  32  air_quality_PM2.5             24070 non-null  float64
#  33  air_quality_PM10              24070 non-null  float64
#  34  air_quality_us-epa-index      24070 non-null  int64
#  35  air_quality_gb-defra-index    24070 non-null  int64
#  36  sunrise                       24070 non-null  object
#  37  sunset                        24070 non-null  object
#  38  moonrise                      24070 non-null  object
#  39  moonset                       24070 non-null  object
#  40  moon_phase                    24070 non-null  object
#  41  moon_illumination             24070 non-null  int64
# dtypes: float64(23), int64(7), object(12)
# memory usage: 7.7+ MB
# None
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  24070.000000  24070.000000        2.407000e+04         24070.000000
# mean      23.099527     80.237659        1.695122e+09            24.323166
# std        5.796304      5.757138        1.092181e+06             3.901488
# min        8.080000     68.970000        1.693286e+09            -5.300000
# 25%       20.270000     76.070000        1.694213e+09            23.000000
# 50%       23.970000     78.680000        1.695163e+09            24.800000
# 75%       26.770000     83.900000        1.696025e+09            26.500000
# max       34.570000     95.800000        1.696972e+09            38.300000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            24070.000000  24070.000000  24070.000000  24070.000000
# mean                75.781475      5.512256      8.875347    186.925634
# std                  7.022537      3.270520      5.257236    101.276077
# min                 22.500000      2.200000      3.600000      1.000000
# 25%                 73.400000      2.900000      4.700000     90.000000
# 50%                 76.600000      4.700000      7.600000    216.000000
# 75%                 79.700000      6.900000     11.200000    270.000000
# max                100.900000     26.800000     43.200000    360.000000
#
#         pressure_mb   pressure_in  ...      gust_kph  \
# count  24070.000000  24070.000000  ...  24070.000000
# mean    1006.048816     29.708192  ...     15.363830
# std        3.177885      0.093842  ...      8.414274
# min      997.000000     29.440000  ...      0.000000
# 25%     1004.000000     29.650000  ...      9.100000
# 50%     1006.000000     29.700000  ...     14.400000
# 75%     1008.000000     29.770000  ...     20.200000
# max     1025.000000     30.260000  ...     75.600000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                 24070.000000       24070.000000
# mean                    594.928396          26.401774
# std                     515.120689          22.886129
# min                     113.500000           0.000000
# 25%                     287.100000           9.400000
# 50%                     454.000000          21.300000
# 75%                     734.300000          37.200000
# max                   11642.500000         171.700000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                  24070.000000                 24070.000000
# mean                       9.238525                     4.721246
# std                        9.582348                    11.501504
# min                        0.000000                     0.000000
# 25%                        3.200000                     0.800000
# 50%                        6.300000                     2.100000
# 75%                       11.800000                     4.700000
# max                      141.200000                   541.700000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count       24070.000000      24070.000000              24070.000000
# mean           50.728288         62.781350                  2.408725
# std            61.950171         73.728859                  1.336316
# min             0.500000          0.700000                  1.000000
# 25%            11.000000         14.600000                  1.000000
# 50%            28.600000         37.300000                  2.000000
# 75%            66.800000         85.200000                  4.000000
# max           899.500000       1043.700000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count                24070.000000       24070.000000
# mean                     4.542792          54.981180
# std                      3.580995          34.926868
# min                      1.000000           0.000000
# 25%                      1.000000          22.000000
# 50%                      3.000000          56.000000
# 75%                      9.000000          91.000000
# max                     10.000000         100.000000
#
# [8 rows x 30 columns]

# %%
import matplotlib.pyplot as plt

# Plot histogram for temperature
plt.hist(data['temperature_celsius'], bins=20, color='skyblue')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.title('Temperature Distribution')
plt.show()

# Plot histogram for precipitation
plt.hist(data['precip_mm'], bins=20, color='lightgreen')
plt.xlabel('Precipitation (mm)')
plt.ylabel('Frequency')
plt.title('Precipitation Distribution')
plt.show()

# %%
import seaborn as sns

# Select relevant columns for correlation analysis
correlation_cols = ['temperature_celsius', 'precip_mm', 'wind_kph', 'humidity', 'air_quality_PM2.5']

# Calculate the correlation matrix
correlation_matrix = data[correlation_cols].corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
data['last_updated'] = pd.to_datetime(data['last_updated'])
data.set_index('last_updated', inplace=True)

# Plot line graph for temperature changes over time
plt.figure(figsize=(12, 6))
plt.plot(data['temperature_celsius'])
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Changes over Time')
plt.show()

# %%
# Scatter plot of latitude vs. longitude to visualize geographical locations
plt.scatter(data['longitude'], data['latitude'], alpha=0.5, color='blue')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographical Distribution of Locations')
plt.show()
